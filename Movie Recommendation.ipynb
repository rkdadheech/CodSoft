# %%
import pandas as pd
df=pd.read_csv("IMdb Movies India.csv",encoding='latin-1')

# %%
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  7919.0  5.841621  1.381777  1.1  4.9  6.0  6.8  10.0

# %%
df[df.duplicated()==True]
# Out:
#                             Name    Year Duration     Genre  Rating Votes  \
# 1250   Arab Ka Sona - Abu Kaalia  (1979)      NaN    Action     NaN   NaN
# 1769                     Balidan  (1992)      NaN     Drama     NaN   NaN
# 4723     First Time - Pehli Baar  (2009)      NaN       NaN     NaN   NaN
# 9713                     Musafir     NaN      NaN  Thriller     NaN   NaN
# 13069                    Shivani  (2019)      NaN     Crime     NaN   NaN
# 13308          Slumdog Karodpati  (2019)  118 min  Thriller     NaN   NaN
#
#                   Director      Actor 1       Actor 2     Actor 3
# 1250        Master Bhagwan    Meena Rai    Dara Singh         NaN
# 1769                   NaN          NaN           NaN         NaN
# 4723          Raja Bundela  Zeenat Aman   Nitin Arora  Raj Babbar
# 9713           Shiva Dagar          NaN           NaN         NaN
# 13069  Ugresh Prasad Ujala      Santosh           NaN         NaN
# 13308        Rajesh Patole  Udhav Garje  Rahul Gavane   Govindrao

# %%
df=df.drop_duplicates()

# %%
import numpy as np
num_cols=df.select_dtypes(include=np.number).columns

# %%
num_cols
# Out:
# Index(['Rating'], dtype='object')

# %%
cat_cols=df.select_dtypes(exclude=np.number).columns

# %%
cat_cols
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Votes', 'Director', 'Actor 1',
#        'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
df.Duration
# Out:
# 0            NaN
# 1        109 min
# 2         90 min
# 3        110 min
# 4        105 min
#           ...
# 15504        NaN
# 15505    129 min
# 15506        NaN
# 15507        NaN
# 15508    130 min
# Name: Duration, Length: 15503, dtype: object

# %%
df.Year
# Out:
# 0           NaN
# 1        (2019)
# 2        (2021)
# 3        (2019)
# 4        (2010)
#           ...
# 15504    (1988)
# 15505    (1999)
# 15506    (2005)
# 15507    (1988)
# 15508    (1998)
# Name: Year, Length: 15503, dtype: object

# %%
df[df.Year=='(2022)']
# Out:
#                                                Name    Year Duration  \
# 640                                       Adipurush  (2022)      NaN
# 1065                                         Animal  (2022)      NaN
# 1537                                Baba Teerthnath  (2022)      NaN
# 1557                                Bachchan Pandey  (2022)      NaN
# 1572                                     Backwaters  (2022)      NaN
# 1921                            Battle of Saraighat  (2022)      NaN
# 2221                                        Bhediya  (2022)      NaN
# 2699                            Chaalbaaz in London  (2022)      NaN
# 3162                                         Cirkus  (2022)  112 min
# 4534                             Ek Villain Returns  (2022)      NaN
# 4692                                        Fighter  (2022)      NaN
# 4693                                        Fighter  (2022)      NaN
# 4845                                       Ganapath  (2022)      NaN
# 4846          Gandabherunda - A Surfing Entertainer  (2022)      NaN
# 5084                                         Ghubar  (2022)      NaN
# 5165                                        Goodbye  (2022)      NaN
# 5344                                        Guthlee  (2022)      NaN
# 5524   Hari Singh Nalwa - Champion of the Khalsa Ji  (2022)      NaN
# 6015                                       Iftikhar  (2022)      NaN
# 6327                                           Jaar  (2022)      NaN
# 7173                                      Kala Pila  (2022)      NaN
# 9042                                         Mayday  (2022)  141 min
# 9304                             Middle Class Crime  (2022)      NaN
# 9482                                   Mom's Coming  (2022)      NaN
# 10372                                Our Love Story  (2022)      NaN
# 10919                               Ponniyin Selvan  (2022)      NaN
# 12265                                        Salaar  (2022)      NaN
# 13443                              State vs Justice  (2022)  120 min
# 13793                                 Tara vs Bilal  (2022)      NaN
# 14125                                    The Intern  (2022)      NaN
# 14249                             The Son of Marwad  (2022)      NaN
# 14360                                         Timir  (2022)  100 min
# 14472                                       Tsunami  (2022)      NaN
# 14640                      Untitled Luv Ranjan Film  (2022)      NaN
# 14752                                     Varchasva  (2022)      NaN
# 14939                                      Vo Ladki  (2022)      NaN
# 15112                          World Bhangra League  (2022)      NaN
# 15319                                        Yudhra  (2022)      NaN
#
#                            Genre  Rating Votes                Director  \
# 640       Action, Drama, History     NaN   NaN                 Om Raut
# 1065               Action, Drama     NaN   NaN     Sandeep Reddy Vanga
# 1537               Comedy, Drama     NaN   NaN            Kunjan Verma
# 1557                      Action     NaN   NaN            Farhad Samji
# 1572             Drama, Thriller     NaN   NaN          Abhinav Thakur
# 1921                     History     NaN   NaN             Sudipto Sen
# 2221              Comedy, Horror     NaN   NaN            Amar Kaushik
# 2699                      Comedy     NaN   NaN         Pankaj Parashar
# 3162                      Comedy     NaN   NaN            Rohit Shetty
# 4534            Action, Thriller     NaN   NaN              Mohit Suri
# 4692            Action, Thriller     NaN   NaN         Siddharth Anand
# 4693     Action, Drama, Thriller     NaN   NaN                 Gayatri
# 4845                      Action     NaN   NaN              Vikas Bahl
# 4846                       Sport     NaN   NaN                    Inam
# 5084              Crime, Mystery     NaN   NaN     Swaminathan Sridhar
# 5165               Comedy, Drama     NaN   NaN              Vikas Bahl
# 5344                       Drama     NaN   NaN          Ishrat R. Khan
# 5524                   Biography     NaN   NaN        Prabhleen Sandhu
# 6015                       Drama     NaN   NaN                     NaN
# 6327                       Drama     NaN   NaN    Phurba Tshering Lama
# 7173                       Drama     NaN   NaN            Limosh Pawar
# 9042             Drama, Thriller     NaN   NaN              Ajay Devgn
# 9304                      Comedy     NaN   NaN         Jyoti Kapur Das
# 9482   Horror, Musical, Thriller     NaN   NaN               Rishiking
# 10372                    Romance     NaN   NaN             Kunal Kohli
# 10919     Drama, Family, Fantasy     NaN   NaN             Mani Ratnam
# 12265                     Action     NaN   NaN          Prashanth Neel
# 13443    Biography, Crime, Drama     NaN   NaN              Jaimin Bal
# 13793                    Romance     NaN   NaN             Samar Iqbal
# 14125    Comedy, Drama, Thriller     NaN   NaN        Deepika Padukone
# 14249     Comedy, Drama, Romance     NaN   NaN          Govind Lugriya
# 14360  Horror, Mystery, Thriller     NaN   NaN        Atul Kumar Dubey
# 14472            Drama, Thriller     NaN   NaN          Madhu Sudhanan
# 14640                     Comedy     NaN   NaN              Luv Ranjan
# 14752                     Action     NaN   NaN            Manish Singh
# 14939             Drama, Romance     NaN   NaN    Praween Kumar Pandey
# 15112                      Drama     NaN   NaN  Parvinder Singh Wraich
# 15319                     Action     NaN   NaN            Ravi Udyawar
#
#                       Actor 1                  Actor 2              Actor 3
# 640                   Prabhas            Saif Ali Khan          Kriti Sanon
# 1065            Ranbir Kapoor         Parineeti Chopra          Anil Kapoor
# 1537               Hanan Baba             Prerna Rawat            Dhruv Lau
# 1557             Akshay Kumar     Jacqueline Fernandez          Kriti Sanon
# 1572                      NaN                      NaN                  NaN
# 1921                      NaN                      NaN                  NaN
# 2221              Kriti Sanon             Varun Dhawan    Abhishek Banerjee
# 2699          Shraddha Kapoor                      NaN                  NaN
# 3162     Jacqueline Fernandez              Pooja Hegde        Ranveer Singh
# 4534             Disha Patani             John Abraham         Arjun Kapoor
# 4692         Deepika Padukone           Hrithik Roshan  Birol Tarkan Yildiz
# 4693                  Pushkar           Hrithik Roshan                  NaN
# 4845              Kriti Sanon             Tiger Shroff                  NaN
# 4846                     Inam          Sanjana Prakash                  NaN
# 5084              Vijay Kumar             Vivek Pandey        Jitendra Rana
# 5165         Amitabh Bachchan        Rashmika Mandanna          Neena Gupta
# 5344            Sanjay Mishra             Subrat Dutta       Kalyanee Mulay
# 5524                      NaN                      NaN                  NaN
# 6015                      NaN                      NaN                  NaN
# 6327         Geetanjali Thapa             Saugat Malla   Anoop Bikram Shahi
# 7173                      NaN                      NaN                  NaN
# 9042         Amitabh Bachchan        Rakul Preet Singh           Ajay Devgn
# 9304             Nikita Dutta       Sunny Singh Nijjar                  NaN
# 9482               Zoya Afroz             Sahil Mishra                 Byom
# 10372            Vardhan Puri             Kaveri Kapur                  NaN
# 10919  Aishwarya Rai Bachchan         Amitabh Bachchan     Aditi Rao Hydari
# 12265                 Prabhas            Shruti Haasan     Mostafiz Mortoza
# 13443                     NaN                      NaN                  NaN
# 13793       Harshvardhan Rane              Angira Dhar                  NaN
# 14125        Amitabh Bachchan                      NaN                  NaN
# 14249            Rk Prajapati         Aryan Maheshwari                  NaN
# 14360            Anurag Sinha        Vaibhavi Upadhyay          Nidhi Bisht
# 14472                     NaN                      NaN                  NaN
# 14640           Ranbir Kapoor          Shraddha Kapoor         Boney Kapoor
# 14752                     NaN                      NaN                  NaN
# 14939      Dharmendra Ahirwar              Sanit Swami                  NaN
# 15112    Harkiran Kaur Wraich  Vinamarjot Singh Wraich                  NaN
# 15319        Malavika Mohanan      Siddhant Chaturvedi         Raghav Juyal

# %%
 #Clean 'Year' and 'Duration' columns
df['Year'] = df['Year'].str.replace(r'[()]', '', regex=True)
df['Duration'] = df['Duration'].str.replace(r' min', '', regex=True)

# %%
df
# Out:
#                                      Name  Year Duration            Genre  \
# 0                                           NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019      109            Drama
# 2                             #Homecoming  2021       90   Drama, Musical
# 3                                 #Yaaram  2019      110  Comedy, Romance
# 4                       ...And Once Again  2010      105            Drama
# ...                                   ...   ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  1988      NaN           Action
# 15505                               Zulmi  1999      129    Action, Drama
# 15506                           Zulmi Raj  2005      NaN           Action
# 15507                       Zulmi Shikari  1988      NaN           Action
# 15508                        Zulm-O-Sitam  1998      130    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df.isnull().sum().sum()
# Out:
# 33494

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         527
# Duration    8264
# Genre       1876
# Rating      7584
# Votes       7583
# Director     524
# Actor 1     1615
# Actor 2     2381
# Actor 3     3140
# dtype: int64

# %%
# column wise null values in descending order 
(df.isnull().sum()*100/df.shape[0]).sort_values(ascending=False)
# Out:
# Duration    53.305812
# Rating      48.919564
# Votes       48.913114
# Actor 3     20.254144
# Actor 2     15.358318
# Genre       12.100884
# Actor 1     10.417339
# Year         3.399342
# Director     3.379991
# Name         0.000000
# dtype: float64

# %%
#Let's drop the first row from the dataset as there is no name available for the movie
df.drop(df.index[0])
# Out:
#                                      Name  Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019      109
# 2                             #Homecoming  2021       90
# 3                                 #Yaaram  2019      110
# 4                       ...And Once Again  2010      105
# 5                    ...Aur Pyaar Ho Gaya  1997      147
# ...                                   ...   ...      ...
# 15504                 Zulm Ko Jala Doonga  1988      NaN
# 15505                               Zulmi  1999      129
# 15506                           Zulmi Raj  2005      NaN
# 15507                       Zulmi Shikari  1988      NaN
# 15508                        Zulm-O-Sitam  1998      130
#
#                         Genre  Rating Votes            Director  \
# 1                       Drama     7.0     8       Gaurav Bakshi
# 2              Drama, Musical     NaN   NaN  Soumyajit Majumdar
# 3             Comedy, Romance     4.4    35          Ovais Khan
# 4                       Drama     NaN   NaN        Amol Palekar
# 5      Comedy, Drama, Musical     4.7   827        Rahul Rawail
# ...                       ...     ...   ...                 ...
# 15504                  Action     4.6    11       Mahendra Shah
# 15505           Action, Drama     4.5   655          Kuku Kohli
# 15506                  Action     NaN   NaN          Kiran Thej
# 15507                  Action     NaN   NaN                 NaN
# 15508           Action, Drama     6.2    20        K.C. Bokadia
#
#                 Actor 1                 Actor 2          Actor 3
# 1          Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 2          Sayani Gupta       Plabita Borthakur       Roy Angana
# 3               Prateik              Ishita Raj  Siddhant Kapoor
# 4          Rajat Kapoor      Rituparna Sengupta      Antara Mali
# 5            Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# ...                 ...                     ...              ...
# 15504  Naseeruddin Shah           Sumeet Saigal    Suparna Anand
# 15505      Akshay Kumar          Twinkle Khanna      Aruna Irani
# 15506   Sangeeta Tiwari                     NaN              NaN
# 15507               NaN                     NaN              NaN
# 15508        Dharmendra              Jaya Prada      Arjun Sarja
#
# [15502 rows x 10 columns]

# %%
df.set_index(np.arange(len(df)),inplace=True)

# %%
df
# Out:
#                                      Name  Year Duration            Genre  \
# 0                                           NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019      109            Drama
# 2                             #Homecoming  2021       90   Drama, Musical
# 3                                 #Yaaram  2019      110  Comedy, Romance
# 4                       ...And Once Again  2010      105            Drama
# ...                                   ...   ...      ...              ...
# 15498                 Zulm Ko Jala Doonga  1988      NaN           Action
# 15499                               Zulmi  1999      129    Action, Drama
# 15500                           Zulmi Raj  2005      NaN           Action
# 15501                       Zulmi Shikari  1988      NaN           Action
# 15502                        Zulm-O-Sitam  1998      130    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15498     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15499     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15500     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15501     NaN   NaN                 NaN               NaN                 NaN
# 15502     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15498    Suparna Anand
# 15499      Aruna Irani
# 15500              NaN
# 15501              NaN
# 15502      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
#Dropping null values
df.dropna(subset=['Year'],inplace=True)
df.dropna(subset=['Genre'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    6205
# Genre          0
# Rating      5319
# Votes       5318
# Director     480
# Actor 1     1110
# Actor 2     1537
# Actor 3     2051
# dtype: int64

# %%
df.Votes
# Out:
# 1          8
# 2        NaN
# 3         35
# 4        NaN
# 5        827
#         ...
# 15498     11
# 15499    655
# 15500    NaN
# 15501    NaN
# 15502     20
# Name: Votes, Length: 13136, dtype: object

# %%
#We are changing the datatype for column 'Duration'
df['Duration']= df['Duration'].apply(pd.to_numeric)

#changing datatype with some string replacing
df["Votes"]=df["Votes"].replace("$5.16M", 516)
df["Votes"] = pd.to_numeric(df['Votes'].str.replace(',',''))

# %%
df.dtypes
# Out:
# Name         object
# Year         object
# Duration    float64
# Genre        object
# Rating      float64
# Votes       float64
# Director     object
# Actor 1      object
# Actor 2      object
# Actor 3      object
# dtype: object

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# %%
df.Rating.describe()
# Out:
# count    7817.000000
# mean        5.839568
# std         1.381472
# min         1.100000
# 25%         4.900000
# 50%         6.000000
# 75%         6.800000
# max        10.000000
# Name: Rating, dtype: float64

# %%
df.dropna(subset=['Rating'],inplace=True)

# %%
#replacing null values with average duration of a movie in India
df['Duration'].fillna(df['Duration'].mean(),inplace=True)

#replacing null values with average votes recived by a Movie
df['Votes'].fillna(df['Votes'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Name          0
# Year          0
# Duration      0
# Genre         0
# Rating        0
# Votes         0
# Director      5
# Actor 1     110
# Actor 2     176
# Actor 3     259
# dtype: int64

# %%
df.dropna(subset=['Actor 1','Actor 2','Actor 3','Director'],inplace=True)

# %%
#sorting the Year and Rating by Rating then selecting the top one
import matplotlib.pyplot as plt
best_rating=df[['Year','Rating']].sort_values(by='Rating',ascending=False).head(1)


#Plotting Bar Graph
fig=plt.figure(figsize=(5,5))
bars=plt.bar(x='Year',height='Rating',data=best_rating,color='seagreen')

plt.xlabel("Year",fontsize=15,fontweight='bold')
plt.ylabel("Rating",fontsize=15,fontweight='bold')
plt.title("Best Rated Year",fontsize=20,fontweight='bold')

plt.xticks(fontweight='bold',rotation=0)
plt.yticks(np.arange(0,13,2),fontweight='bold')


#Plotting the labels for Bars for better visualization
for ele in bars:
    plt.text(ele.get_x()+(ele.get_width()/2),ele.get_y()+ele.get_height(),ele.get_height(),color='black',ha='center',
             va='bottom',fontsize=15)

# %%
df[df.Rating==10]
# Out:
#                  Name  Year  Duration           Genre  Rating  Votes  \
# 8336  Love Qubool Hai  2020      94.0  Drama, Romance    10.0    5.0
#
#              Director    Actor 1         Actor 2              Actor 3
# 8336  Saif Ali Sayeed  Ahaan Jha  Mahesh Narayan  Rajasree Rajakumari

# %%
 #sorting Values of Year and Rating by Rating then selecting top 5
top5_rating=df[['Year','Rating']].sort_values(by='Rating',ascending=False).head()

#Plotting Bar Graph
bars=top5_rating.plot(kind='bar',x='Year',y='Rating',color='purple',legend=None,figsize=(7,6))

plt.xlabel("Year",fontsize=15,fontweight='bold')
plt.ylabel("Rating",fontsize=15,fontweight='bold')
plt.title("Overall Top 5 Ratings",fontsize=20,fontweight='bold')

plt.xticks(fontweight='bold',rotation=0)
plt.yticks(np.arange(0,13,2),fontweight='bold')


#Plotting Labels for bars
for bar in bars.patches:
    bars.annotate(format(bar.get_height(),'.1f'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
df.Rating.sort_values(ascending=False).head()
# Out:
# 8336     10.0
# 5407      9.7
# 2561      9.6
# 14216     9.4
# 5074      9.4
# Name: Rating, dtype: float64

# %%
df[df.Rating.isin([10.0,9.7,9.6,9.4])]
# Out:
#                       Name  Year    Duration             Genre  Rating  Votes  \
# 2561                 Breed  2020  132.255155             Drama     9.6   48.0
# 5074          Gho Gho Rani  2019  105.000000  History, Romance     9.4   47.0
# 5407            Half Songs  2021   79.000000    Music, Romance     9.7    7.0
# 6849                  June  2021   93.000000             Drama     9.4   18.0
# 8336       Love Qubool Hai  2020   94.000000    Drama, Romance    10.0    5.0
# 14216  The Reluctant Crime  2020  113.000000             Drama     9.4   16.0
#
#               Director            Actor 1          Actor 2  \
# 2561       Bobby Kumar        Bobby Kumar           Ashfaq
# 5074      Munni Pankaj  Nishi Neha Mishra     Pankaj Kamal
# 5407       Sriram Raja       Raj Banerjee  Emon Chatterjee
# 6849    Suhrud Godbole     Vaibhav Khisti   Nilesh Divekar
# 8336   Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# 14216    Arvind Pratap    Dharmendra Ahir   Awanish Kotnal
#
#                    Actor 3
# 2561        Fasih Choudhry
# 5074           Akash Kumar
# 5407     Purshottam Mulani
# 6849        Jitendra Joshi
# 8336   Rajasree Rajakumari
# 14216         Rakhi Mansha

# %%
top_5_movies = df.nlargest(5, 'Rating')

# Extract the names of the top 5 movies,with ratings
top_5_movie_names = top_5_movies[['Name','Rating']]

print(top_5_movie_names)
# Out:
#                  Name  Rating
# 8336  Love Qubool Hai    10.0
# 5407       Half Songs     9.7
# 2561            Breed     9.6
# 5074     Gho Gho Rani     9.4
# 6849             June     9.4

# %%
 #intializing figure of the chart
import seaborn as sns
plt.figure(figsize=(8, 8))


#sorting Name and Rating by Rating then selecting top 10
top_movies= df[['Name','Rating']].sort_values(by='Rating',ascending=False).head(10)

#Plotting Bar chart
plots = sns.barplot(x="Rating", y="Name", data=top_movies)
  

#Plotting Labels for bars
for bar in plots.patches:
    
    plots.annotate(format(bar.get_width(),'.2f'), 
                   (bar.get_x() + bar.get_width()+0.3, 
                    bar.get_y()+0.5), ha='center', va='center',
                   size=15, xytext=(5,10),
                   textcoords='offset points')

    
plt.xlabel("Rating",fontsize=15,fontweight='bold')
plt.ylabel("Name",fontsize=15,fontweight='bold')
plt.title("Top 10 Movies based on Ratings",fontsize=20,fontweight='bold')

plt.xticks(np.arange(0,13,2),fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
#Making Series for the all the columns of Actors
Actor1=df['Actor 1']
Actor2=df['Actor 2']
Actor3=df['Actor 3']

#Concatinating the series in one series
Actors = pd.concat([Actor1,Actor2,Actor3])

#sorting series by counts then selecting top 10
frequent_actor=Actors.value_counts().sort_values(ascending=False).head(10)

#Plotting Bar graph
frequent_actor.sort_values().plot(kind='barh',color='#029386',figsize=(6,8))

plt.title('Top 10 Actors',fontweight='bold',fontsize=20)
plt.xlabel('Count',fontweight='bold',fontsize=15)
plt.ylabel('Actor',fontweight='bold',fontsize=15)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
#Importing Counter to count distinct values form perticular series
from collections import Counter

#creating series for Genre column
Genre=df['Genre']

#initializing counter object
Genre_counter=Counter()

#splitting the values if one row contain more than two values
for response in Genre:
    Genre_counter.update(response.split(','))
    
#Printing the top 10 values with occured most of the time
print(Genre_counter.most_common(10))

#Creating List to store the Counter values
Genres=[]
frequency=[]

for items in Genre_counter.most_common(10):
    Genres.append(items[0])
    frequency.append(items[1])

    
#As Drama Appears more than twice in the List
Genres.pop(2)
frequency.pop(2)
# Out:
# [('Drama', 2481), (' Drama', 2373), ('Action', 2272), (' Romance', 1496), ('Comedy', 1178), (' Crime', 765), (' Thriller', 733), (' Family', 571), (' Comedy', 417), (' Musical', 372)]
# 2272

# %%
#Plottin bar graph
fig= plt.figure(figsize=(10,6))
plt.bar(Genres,frequency,color='#348ABD')
plt.title('Top 10 Genres',fontweight='bold',fontsize=20)
plt.xlabel('Genre',fontweight='bold',fontsize=15)
plt.ylabel('Count',fontweight='bold',fontsize=15)
plt.xticks(fontweight='bold',rotation=0)
plt.yticks(fontweight='bold')
plt.show()

# %%
#Creating a Funtion for plotting graphs 
def top10(column):
    global df
    df[column].value_counts().sort_values(ascending=False).head(10).plot(kind='bar',
                                                                            figsize=(15,6),color='#988ED5')
    
    plt.xlabel(column,fontsize=15,fontweight='bold')
    plt.ylabel('Count',fontweight='bold',fontsize=15)
    plt.title("Top 10 {}".format(column),fontsize=25,fontweight='bold')
    plt.xticks(rotation=0,fontsize=9,fontweight='bold')
    plt.yticks(fontsize=10,fontweight='bold')
    plt.show()

# %%
#Looping the columns then calling the funtion to plot graph
cols=['Director','Actor 1','Actor 2','Actor 3']
for items in cols:
    top10(items)

# %%
def distribution(column):
    global df
    fig=plt.figure(figsize=(8,6))
    sns.displot(x=column,data=df,palette='gist_earth_r',bins=25)
    plt.xlabel(column,fontweight='bold',fontsize=15)
    plt.ylabel('Density',fontweight='bold',fontsize=15)
    plt.title('Distribution of {}'.format(column),fontweight='bold',fontsize=20)
    plt.xticks(fontweight='bold')
    plt.yticks(fontweight='bold')
    plt.show()
    
df['Released_Year']= df.index.astype('int64')

# %%
lis=['Rating','Duration','Released_Year','Votes']
i=0
while i< len(lis):
    distribution(lis[i])
    i+=1
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9276\3975610329.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(x=column,data=df,palette='gist_earth_r',bins=25)
# C:\Users\dell\AppData\Local\Temp\ipykernel_9276\3975610329.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(x=column,data=df,palette='gist_earth_r',bins=25)
# C:\Users\dell\AppData\Local\Temp\ipykernel_9276\3975610329.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(x=column,data=df,palette='gist_earth_r',bins=25)
# C:\Users\dell\AppData\Local\Temp\ipykernel_9276\3975610329.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(x=column,data=df,palette='gist_earth_r',bins=25)

# %%
fig= plt.figure(figsize=(7,7))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9276\1214175180.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# <Axes: >

# %%
((df.Genre.value_counts(normalize=True)*100).head()).plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Genre'>

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Released_Year'],
#       dtype='object')

# %%
df["Actor"] = df['Actor 1'] + ', ' + df['Actor 2'] + ', ' + df['Actor 3']
df["Directors"] = df['Director'].astype('category').cat.codes
df["Genres"] = df['Genre'].astype('category').cat.codes
df["Actors"] = df['Actor'].astype('category').cat.codes
df.head(5)
# Out:
#                                  Name  Year  Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019     109.0
# 3                             #Yaaram  2019     110.0
# 5                ...Aur Pyaar Ho Gaya  1997     147.0
# 6                           ...Yahaan  2005     142.0
# 8                  ?: A Question Mark  2012      82.0
#
#                        Genre  Rating   Votes        Director          Actor 1  \
# 1                      Drama     7.0     8.0   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4    35.0      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7   827.0    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1086.0  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6   326.0   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  Released_Year  \
# 1          Vivek Ghamande    Arvind Jangid              1
# 3              Ishita Raj  Siddhant Kapoor              3
# 5  Aishwarya Rai Bachchan    Shammi Kapoor              5
# 6          Minissha Lamba   Yashpal Sharma              6
# 8          Muntazir Ahmad     Kiran Bhatia              8
#
#                                                Actor  Directors  Genres  \
# 1        Rasika Dugal, Vivek Ghamande, Arvind Jangid        755     252
# 3               Prateik, Ishita Raj, Siddhant Kapoor       1637     205
# 5  Bobby Deol, Aishwarya Rai Bachchan, Shammi Kapoor       1881     175
# 6    Jimmy Sheirgill, Minissha Lamba, Yashpal Sharma       2486     315
# 8            Yash Dave, Muntazir Ahmad, Kiran Bhatia        161     351
#
#    Actors
# 1    5222
# 3    4494
# 5    1447
# 6    2774
# 8    7416

# %%
ax = sns.boxplot(data=df, y='Genres')
ax.set_ylabel('Genres')
ax.set_title('Box Plot of Genres')
plt.show()

# %%
Q1 = df['Genres'].quantile(0.25)
Q3 = df['Genres'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Genres'] >= lower_bound) & (df['Genres'] <= upper_bound)]
df.head()
# Out:
#                                  Name  Year  Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019     109.0
# 3                             #Yaaram  2019     110.0
# 5                ...Aur Pyaar Ho Gaya  1997     147.0
# 6                           ...Yahaan  2005     142.0
# 8                  ?: A Question Mark  2012      82.0
#
#                        Genre  Rating   Votes        Director          Actor 1  \
# 1                      Drama     7.0     8.0   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4    35.0      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7   827.0    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1086.0  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6   326.0   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  Released_Year  \
# 1          Vivek Ghamande    Arvind Jangid              1
# 3              Ishita Raj  Siddhant Kapoor              3
# 5  Aishwarya Rai Bachchan    Shammi Kapoor              5
# 6          Minissha Lamba   Yashpal Sharma              6
# 8          Muntazir Ahmad     Kiran Bhatia              8
#
#                                                Actor  Directors  Genres  \
# 1        Rasika Dugal, Vivek Ghamande, Arvind Jangid        755     252
# 3               Prateik, Ishita Raj, Siddhant Kapoor       1637     205
# 5  Bobby Deol, Aishwarya Rai Bachchan, Shammi Kapoor       1881     175
# 6    Jimmy Sheirgill, Minissha Lamba, Yashpal Sharma       2486     315
# 8            Yash Dave, Muntazir Ahmad, Kiran Bhatia        161     351
#
#    Actors
# 1    5222
# 3    4494
# 5    1447
# 6    2774
# 8    7416

# %%
Q1 = df['Directors'].quantile(0.25)
Q3 = df['Directors'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Directors'] >= lower_bound) & (df['Directors'] <= upper_bound)]
df.head(5)
# Out:
#                                  Name  Year  Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019     109.0
# 3                             #Yaaram  2019     110.0
# 5                ...Aur Pyaar Ho Gaya  1997     147.0
# 6                           ...Yahaan  2005     142.0
# 8                  ?: A Question Mark  2012      82.0
#
#                        Genre  Rating   Votes        Director          Actor 1  \
# 1                      Drama     7.0     8.0   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4    35.0      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7   827.0    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1086.0  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6   326.0   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  Released_Year  \
# 1          Vivek Ghamande    Arvind Jangid              1
# 3              Ishita Raj  Siddhant Kapoor              3
# 5  Aishwarya Rai Bachchan    Shammi Kapoor              5
# 6          Minissha Lamba   Yashpal Sharma              6
# 8          Muntazir Ahmad     Kiran Bhatia              8
#
#                                                Actor  Directors  Genres  \
# 1        Rasika Dugal, Vivek Ghamande, Arvind Jangid        755     252
# 3               Prateik, Ishita Raj, Siddhant Kapoor       1637     205
# 5  Bobby Deol, Aishwarya Rai Bachchan, Shammi Kapoor       1881     175
# 6    Jimmy Sheirgill, Minissha Lamba, Yashpal Sharma       2486     315
# 8            Yash Dave, Muntazir Ahmad, Kiran Bhatia        161     351
#
#    Actors
# 1    5222
# 3    4494
# 5    1447
# 6    2774
# 8    7416

# %%
ax = sns.boxplot(data=df, y='Actors')
ax.set_ylabel('Actors')
ax.set_title('Box Plot of Actors')
plt.show()

# %%
Q1 = df['Actors'].quantile(0.25)
Q3 = df['Actors'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['Actors'] >= lower_bound) & (df['Actors'] <= upper_bound)]
df.head(5)
# Out:
#                                  Name  Year  Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019     109.0
# 3                             #Yaaram  2019     110.0
# 5                ...Aur Pyaar Ho Gaya  1997     147.0
# 6                           ...Yahaan  2005     142.0
# 8                  ?: A Question Mark  2012      82.0
#
#                        Genre  Rating   Votes        Director          Actor 1  \
# 1                      Drama     7.0     8.0   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4    35.0      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7   827.0    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1086.0  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6   326.0   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  Released_Year  \
# 1          Vivek Ghamande    Arvind Jangid              1
# 3              Ishita Raj  Siddhant Kapoor              3
# 5  Aishwarya Rai Bachchan    Shammi Kapoor              5
# 6          Minissha Lamba   Yashpal Sharma              6
# 8          Muntazir Ahmad     Kiran Bhatia              8
#
#                                                Actor  Directors  Genres  \
# 1        Rasika Dugal, Vivek Ghamande, Arvind Jangid        755     252
# 3               Prateik, Ishita Raj, Siddhant Kapoor       1637     205
# 5  Bobby Deol, Aishwarya Rai Bachchan, Shammi Kapoor       1881     175
# 6    Jimmy Sheirgill, Minissha Lamba, Yashpal Sharma       2486     315
# 8            Yash Dave, Muntazir Ahmad, Kiran Bhatia        161     351
#
#    Actors
# 1    5222
# 3    4494
# 5    1447
# 6    2774
# 8    7416

# %%
from sklearn.model_selection import train_test_split

# %%
Input = df.drop(['Name', 'Genre', 'Rating', 'Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Actor'], axis=1)
Output = df['Rating']

# %%
Input.head(5)
# Out:
#    Year  Duration   Votes  Released_Year  Directors  Genres  Actors
# 1  2019     109.0     8.0              1        755     252    5222
# 3  2019     110.0    35.0              3       1637     205    4494
# 5  1997     147.0   827.0              5       1881     175    1447
# 6  2005     142.0  1086.0              6       2486     315    2774
# 8  2012      82.0   326.0              8        161     351    7416

# %%
Output.head(5)
# Out:
# 1    7.0
# 3    4.4
# 5    4.7
# 6    7.4
# 8    5.6
# Name: Rating, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(Input, Output, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score as score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
df.dtypes
# Out:
# Name              object
# Year               int64
# Duration         float64
# Genre             object
# Rating           float64
# Votes            float64
# Director          object
# Actor 1           object
# Actor 2           object
# Actor 3           object
# Released_Year      int64
# Actor             object
# Directors          int16
# Genres             int16
# Actors             int16
# dtype: object

# %%
def evaluate_model(y_true, y_pred, model_name):
    print("Model: ", model_name)
    print("Accuracy = {:0.2f}%".format(score(y_true, y_pred)*100))
    print("Mean Squared Error = {:0.2f}\n".format(mean_squared_error(y_true, y_pred, squared=False)))
    return round(score(y_true, y_pred)*100, 2)

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
lr_preds = LR.predict(x_test)

RFR = RandomForestRegressor(n_estimators=100, random_state=1)
RFR.fit(x_train, y_train)
rf_preds = RFR.predict(x_test)

DTR = DecisionTreeRegressor(random_state=1)
DTR.fit(x_train, y_train)
dt_preds = DTR.predict(x_test)

XGBR = XGBRegressor(n_estimators=100, random_state=1)
XGBR.fit(x_train, y_train)
xgb_preds = XGBR.predict(x_test)

GBR = GradientBoostingRegressor(n_estimators=100, random_state=60)
GBR.fit(x_train, y_train)
gb_preds = GBR.predict(x_test)

KNR = KNeighborsRegressor(n_neighbors=5)
KNR.fit(x_train, y_train)
knn_preds = KNR.predict(x_test)

# %%
LRScore = evaluate_model(y_test, lr_preds, "LINEAR REGRESSION")
RFScore = evaluate_model(y_test, rf_preds, "RANDOM FOREST")
DTScore = evaluate_model(y_test, dt_preds, "DECEISION TREE")
XGBScore = evaluate_model(y_test, xgb_preds, "EXTENDED GRADIENT BOOSTING")
GBScore = evaluate_model(y_test, gb_preds, "GRADIENT BOOSTING")
KNNScore = evaluate_model(y_test, knn_preds, "K NEAREST NEIGHBORS")
# Out:
# Model:  LINEAR REGRESSION
# Accuracy = 9.23%
# Mean Squared Error = 1.30
#
# Model:  RANDOM FOREST
# Accuracy = 35.62%
# Mean Squared Error = 1.10
#
# Model:  DECEISION TREE
# Accuracy = -29.46%
# Mean Squared Error = 1.56
#
# Model:  EXTENDED GRADIENT BOOSTING
# Accuracy = 32.95%
# Mean Squared Error = 1.12
#
# Model:  GRADIENT BOOSTING
# Accuracy = 35.98%
# Mean Squared Error = 1.10
#
# Model:  K NEAREST NEIGHBORS
# Accuracy = -9.51%
# Mean Squared Error = 1.43

# %%
models = pd.DataFrame(
    {
        "MODELS": ["Linear Regression", "Random Forest", "Decision Tree", "Gradient Boosting", "Extended Gradient Boosting", "K Nearest Neighbors"],
        "SCORES": [LRScore, RFScore, DTScore, GBScore, XGBScore,KNNScore]
    }
)
models.sort_values(by='SCORES', ascending=False)
# Out:
#                        MODELS  SCORES
# 3           Gradient Boosting   35.98
# 1               Random Forest   35.62
# 4  Extended Gradient Boosting   32.95
# 0           Linear Regression    9.23
# 5         K Nearest Neighbors   -9.51
# 2               Decision Tree  -29.46
